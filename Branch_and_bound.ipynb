# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusFreitas-C/Branch_and_Bound/blob/main/Branch_and_bound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mip
from mip import *
import math as mt

# %%
# Função para ler os dados das instancias

def load_data_inst(file_path):
  with open(file_path, 'r') as file:
    first_line = file.readline().strip()
    vars_qty, constr_qty = map(int, first_line.split())

    second_line = file.readline().strip()
    k = list(map(float, second_line.split()))

    c = []
    for _ in range(constr_qty):
        line = file.readline().strip()
        c.append(list(map(float, line.split())))

    return vars_qty, constr_qty, k, c

# %%
def save(model, filename):
  model.write(filename)
  with open(filename, 'r') as file:
      return file.read()

# %%
stack = []

# %%
def branch_and_bound(model, x, fp):
    global zp, zd
    global iter

    # Criando cópias do modelo para o ramo inferior e superior
    model_lower = model.copy()
    model_upper = model.copy()

    # Otimiza o modelo atual
    status = model.optimize()

    fp.write("--" * 70 + "\n")
    fp.write(f"Iteração {iter}\n" +
           (f"Resultado da Relaxação Linear: {model.objective_value:.3f}\n" if status != OptimizationStatus.INFEASIBLE else "\n"))

    # Adiciona o índice atual à pilha de iterações e incrementa iterador
    stack.insert(0, iter)
    iter += 1

    # Verificação de poda por inviabilidade
    if status in (OptimizationStatus.INFEASIBLE, OptimizationStatus.NO_SOLUTION_FOUND):
        return None, False

    # Atualiza o limite dual (zd) se o valor do objetivo atual for menor
    zd = min(zd, model.objective_value)

    fp.write("Variáveis: \n")
    for v in model.vars:
      fp.write(f"{v.name} = {v.x:.2f}\n")

    # Inicialização de variáveis para verificar se há solução fracionária
    best_var = None
    found_fractional = False
    closest_to_half = 0.5  # Define uma base inicial para verificar quão próxima uma variável está de 0.5

    # Itera sobre as variáveis do modelo para encontrar a mais próxima de 0.5
    for v in model.vars:
        if 0 < v.x < 1:  # Verifica se a variável é fracionária
            dist_to_half = abs(v.x - 0.5)
            if dist_to_half < closest_to_half:
                closest_to_half = dist_to_half
                best_var = v
                found_fractional = True

    # Se não houver variáveis fracionárias, a solução é inteira, podemos retornar o modelo
    if not found_fractional:
        return model, True

    fp.write(f"Variável escolhida: {best_var} = {best_var.x:.2f}\n")

    # Poda por limitante (verifica se a solução atual é pior que a melhor já encontrada)
    if zp >= model.objective_value:
        return model, False

    fp.write(f"\nRestrições:")
    constraints = save(model, "model.lp")
    fp.write(f"\n\n{constraints}\n")

    # Ramo esquerdo: adiciona a restrição de que a melhor variável fracionária seja 0
    model_lower += best_var == 0
    left_result, is_integral = branch_and_bound(model_lower, x, fp)

    # Remove a iteração da pilha após a chamada recursiva
    stack.pop(0)
    if is_integral and (zp == -mt.inf or left_result.objective_value > zp):
        zp = left_result.objective_value

    # Ramo direito: adiciona a restrição de que a melhor variável fracionária seja 1
    model_upper += best_var == 1
    right_result, is_integral = branch_and_bound(model_upper, x, fp)

    # Remove a iteração da pilha após a chamada recursiva
    stack.pop(0)
    if is_integral and (zp == -mt.inf or right_result.objective_value > zp):
        zp = right_result.objective_value

    # Retorna o melhor resultado encontrado ou o modelo atual se nenhum foi encontrado
    return left_result if left_result is not None else model, False

# %%
def run_tests():
  for i in range(4):
    global zp, zd
    global iter

    zp, zd = -mt.inf, -mt.inf
    iter = 1

    vars_qty, constr_qty, k, c = load_data_inst(f"teste{i+1}.txt")

    model = Model(sense=MAXIMIZE, solver_name=CBC)

    x = [model.add_var(var_type=CONTINUOUS, name=f"x_{j}", lb=0, ub=1) for j in range(vars_qty)]
    model.objective = xsum(k[j] * x[j] for j in range(vars_qty))

    for n in range(constr_qty):
        model += xsum(c[n][j] * x[j] for j in range(vars_qty)) <= c[n][len(c[n]) - 1]

    fres = open(f"resposta{i+1}.txt", "w")

    branch_and_bound(model, x, fres)

    print(f"Solution Value {i+1}: {zp}")
    fres.write(f"Solution Value {i+1}: {zp}")

    fres.close()

run_tests()
# Out:
# Solution Value 1: 20.0
# Solution Value 2: 24.0
# Solution Value 3: 19.0
# Solution Value 4: 10.0

# %%
fres = open(f"resposta1.txt", "r")
print(fres.read())
fres.close()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 1
# Resultado da Relaxação Linear: 28.750
# Variáveis:
# x_0 = 0.00
# x_1 = 0.87
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_1 = 0.87
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 2
# Resultado da Relaxação Linear: 26.222
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.78
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_2 = 0.78
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 3
# Resultado da Relaxação Linear: 25.444
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.78
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.78
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 4
# Resultado da Relaxação Linear: 24.200
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.70
# Variável escolhida: x_6 = 0.70
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 5
# Resultado da Relaxação Linear: 21.400
# Variáveis:
# x_0 = 0.70
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_0 = 0.70
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 0
# constr(14):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 6
# Resultado da Relaxação Linear: 20.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 1.00
# x_6 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 7
# Resultado da Relaxação Linear: 17.714
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.57
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_4 = 0.57
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 8
# Resultado da Relaxação Linear: 21.714
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.57
# x_5 = 1.00
# x_6 = 1.00
# Variável escolhida: x_4 = 0.57
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 0
# constr(14):  x_6 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 9
# Resultado da Relaxação Linear: 16.800
# Variáveis:
# x_0 = 0.40
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# Variável escolhida: x_0 = 0.40
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 10
# Resultado da Relaxação Linear: 21.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.50
# x_6 = 1.00
# Variável escolhida: x_5 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 0
# constr(14):  x_6 = 1
# constr(15):  x_4 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 11
# Resultado da Relaxação Linear: 16.600
# Variáveis:
# x_0 = 0.30
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 1.00
# Variável escolhida: x_0 = 0.30
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 12
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 13
# Resultado da Relaxação Linear: 24.143
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.71
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_4 = 0.71
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 14
# Resultado da Relaxação Linear: 20.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.50
# Variável escolhida: x_6 = 0.50
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 15
# Resultado da Relaxação Linear: 23.667
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 1.00
# x_5 = 0.67
# x_6 = 0.00
# Variável escolhida: x_5 = 0.67
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 0
# constr(13):  x_3 = 1
# constr(14):  x_4 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 16
# Resultado da Relaxação Linear: 19.400
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.40
# Variável escolhida: x_6 = 0.40
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 17
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 18
# Resultado da Relaxação Linear: 25.143
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.71
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_4 = 0.71
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 19
# Resultado da Relaxação Linear: 21.889
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.56
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.56
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# constr(13):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 20
# Resultado da Relaxação Linear: 21.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.50
# Variável escolhida: x_6 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# constr(13):  x_4 = 0
# constr(14):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 21
# Resultado da Relaxação Linear: 19.000
# Variáveis:
# x_0 = 0.50
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_0 = 0.50
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 22
# Resultado da Relaxação Linear: 15.667
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.17
# x_6 = 1.00
# Variável escolhida: x_5 = 0.17
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 23
# Resultado da Relaxação Linear: 18.333
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.33
# x_6 = 0.00
# Variável escolhida: x_5 = 0.33
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 24
# Resultado da Relaxação Linear: 24.667
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.67
# x_6 = 0.00
# Variável escolhida: x_5 = 0.67
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# constr(13):  x_4 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 25
# Resultado da Relaxação Linear: 21.111
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.44
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.44
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# constr(13):  x_4 = 1
# constr(14):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 26
# Resultado da Relaxação Linear: 20.400
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.40
# Variável escolhida: x_6 = 0.40
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 0
# constr(12):  x_2 = 1
# constr(13):  x_4 = 1
# constr(14):  x_5 = 0
# constr(15):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 27
# Resultado da Relaxação Linear: 18.800
# Variáveis:
# x_0 = 0.40
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_0 = 0.40
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 28
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 29
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 30
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 31
# Resultado da Relaxação Linear: 28.571
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.86
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_4 = 0.86
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 32
# Resultado da Relaxação Linear: 25.333
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.67
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_2 = 0.67
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 33
# Resultado da Relaxação Linear: 24.667
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.67
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.67
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 34
# Resultado da Relaxação Linear: 23.600
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.60
# Variável escolhida: x_6 = 0.60
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 0
# constr(14):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 35
# Resultado da Relaxação Linear: 21.200
# Variáveis:
# x_0 = 0.60
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# Variável escolhida: x_0 = 0.60
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 0
# constr(14):  x_3 = 0
# constr(15):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 36
# Resultado da Relaxação Linear: 20.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 37
# Resultado da Relaxação Linear: 15.333
# Variáveis:
# x_0 = 1.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.33
# x_6 = 0.00
# Variável escolhida: x_5 = 0.33
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 38
# Resultado da Relaxação Linear: 19.333
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.33
# x_6 = 1.00
# Variável escolhida: x_5 = 0.33
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 39
# Resultado da Relaxação Linear: 22.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.50
# x_6 = 0.00
# Variável escolhida: x_5 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 0
# constr(14):  x_3 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 40
# Resultado da Relaxação Linear: 18.800
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.30
# Variável escolhida: x_6 = 0.30
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 41
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 42
# Resultado da Relaxação Linear: 23.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.50
# x_6 = 0.00
# Variável escolhida: x_5 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 43
# Resultado da Relaxação Linear: 20.333
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 1.00
# x_3 = 0.33
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.33
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 0
# constr(13):  x_2 = 1
# constr(14):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 44
# Resultado da Relaxação Linear: 19.800
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.30
# Variável escolhida: x_6 = 0.30
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 45
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 46
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 47
# Resultado da Relaxação Linear: 28.333
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.83
# x_6 = 0.00
# Variável escolhida: x_5 = 0.83
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 48
# Resultado da Relaxação Linear: 24.444
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.56
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_2 = 0.56
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 1
# constr(13):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 49
# Resultado da Relaxação Linear: 23.889
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.56
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_3 = 0.56
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 1
# constr(13):  x_5 = 0
# constr(14):  x_2 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 50
# Resultado da Relaxação Linear: 23.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.50
# Variável escolhida: x_6 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 1
# constr(13):  x_5 = 0
# constr(14):  x_2 = 0
# constr(15):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 51
# Resultado da Relaxação Linear: 21.000
# Variáveis:
# x_0 = 0.50
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# Variável escolhida: x_0 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -2 x_0 -10 x_1 -8 x_2 -7 x_3 -10 x_4 -10 x_5 -6 x_6
# Subject To
# constr(0):  5 x_0 + 7 x_1 + 8 x_2 + x_3 + 7 x_4 + 5 x_5 + 6 x_6 <= 20
# constr(1):  x_0 + 6 x_1 + 4 x_2 + 9 x_3 + 10 x_4 + 6 x_5 + 10 x_6 <= 30
# constr(2):  4 x_0 + 4 x_1 + 4 x_2 + x_3 + 5 x_4 + 5 x_5 + 10 x_6 <= 40
# constr(3):  3 x_0 + 10 x_1 + 8 x_2 + x_3 + 3 x_4 + 3 x_5 + 8 x_6 <= 30
# constr(4):  10 x_0 + 8 x_1 + 9 x_2 + 9 x_3 + 7 x_4 + 6 x_5 + 10 x_6 <= 20
# constr(5):  6 x_0 + 6 x_1 + 3 x_2 + 6 x_3 + 3 x_4 + 7 x_5 + 2 x_6 <= 80
# constr(6):  7 x_0 + 10 x_1 + 7 x_2 + 8 x_3 + 7 x_4 + 8 x_5 + 7 x_6 <= 100
# constr(7):  9 x_0 + 8 x_1 + x_2 + x_3 + 8 x_4 + 10 x_5 + 2 x_6 <= 90
# constr(8):  x_0 + 5 x_1 + 3 x_2 + 10 x_3 + 2 x_4 + 4 x_5 + 9 x_6 <= 70
# constr(9):  9 x_0 + 6 x_1 + x_2 + 4 x_3 + 7 x_4 + 5 x_5 + 10 x_6 <= 60
# constr(10):  5 x_0 + 7 x_1 + 4 x_2 + 4 x_3 + 3 x_4 + 4 x_5 + 10 x_6 <= 40
# constr(11):  x_1 = 1
# constr(12):  x_4 = 1
# constr(13):  x_5 = 0
# constr(14):  x_2 = 0
# constr(15):  x_3 = 0
# constr(16):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 52
# Resultado da Relaxação Linear: 20.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 53
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 54
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 55
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 56
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 57
#
# Solution Value 1: 20.0

# %%
fres = open(f"resposta2.txt", "r")
print(fres.read())
fres.close()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 1
# Resultado da Relaxação Linear: 28.455
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.09
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.55
# Variável escolhida: x_8 = 0.55
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 2
# Resultado da Relaxação Linear: 27.714
# Variáveis:
# x_0 = 0.37
# x_1 = 1.00
# x_2 = 0.16
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.37
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# constr(9):  x_8 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 3
# Resultado da Relaxação Linear: 27.200
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.40
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.40
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# constr(9):  x_8 = 0
# constr(10):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 4
# Resultado da Relaxação Linear: 26.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.20
# x_8 = 0.00
# Variável escolhida: x_7 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# constr(9):  x_8 = 0
# constr(10):  x_0 = 0
# constr(11):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 5
# Resultado da Relaxação Linear: 25.400
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.20
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_2 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# constr(9):  x_8 = 0
# constr(10):  x_0 = 0
# constr(11):  x_4 = 0
# constr(12):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 6
# Resultado da Relaxação Linear: 25.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.20
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_3 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -7 x_1 -7 x_2 -5 x_3 -8 x_4 -8 x_5 -9 x_6 -10 x_7 -7 x_8
# Subject To
# constr(0):  x_0 + 3 x_1 + x_2 + 3 x_3 + 3 x_4 + 7 x_5 + 2 x_6 + x_7 + 4 x_8 <= 80
# constr(1):  7 x_0 + 6 x_1 + 10 x_2 + x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 7 x_7 + x_8 <= 90
# constr(2):  3 x_0 + 2 x_1 + x_2 + 3 x_3 + 3 x_4 + 2 x_5 + x_6 + 6 x_7 + 5 x_8 <= 10
# constr(3):  10 x_0 + 8 x_1 + 3 x_2 + 6 x_3 + 10 x_4 + 7 x_5 + 3 x_6 + 10 x_7 + 4 x_8 <= 30
# constr(4):  2 x_0 + 8 x_1 + 6 x_2 + 5 x_3 + 6 x_4 + 6 x_5 + 9 x_6 + 7 x_7 + 2 x_8 <= 80
# constr(5):  3 x_0 + 10 x_1 + x_2 + 9 x_3 + 2 x_4 + 7 x_5 + 7 x_6 + 9 x_7 + 10 x_8 <= 90
# constr(6):  x_0 + 7 x_1 + 10 x_2 + 10 x_3 + 5 x_4 + 2 x_5 + 9 x_6 + 10 x_7 + 2 x_8 <= 20
# constr(7):  10 x_0 + 3 x_1 + 2 x_2 + 3 x_3 + 10 x_4 + 2 x_5 + x_6 + 9 x_7 + 7 x_8 <= 10
# constr(8):  2 x_0 + x_1 + 7 x_2 + 10 x_3 + x_4 + x_5 + 2 x_6 + x_7 + x_8 <= 50
# constr(9):  x_8 = 0
# constr(10):  x_0 = 0
# constr(11):  x_4 = 0
# constr(12):  x_7 = 0
# constr(13):  x_2 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 7
# Resultado da Relaxação Linear: 24.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 8
# Resultado da Relaxação Linear: 21.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.89
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.89
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 9
# Resultado da Relaxação Linear: 23.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.89
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.89
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 10
# Resultado da Relaxação Linear: 19.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 1.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 11
# Resultado da Relaxação Linear: 8.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 12
# Resultado da Relaxação Linear: 7.000
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 13
# Resultado da Relaxação Linear: 24.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 1.00
# Solution Value 2: 24.0

# %%
fres = open(f"resposta3.txt", "r")
print(fres.read())
fres.close()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 1
# Resultado da Relaxação Linear: 24.913
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.13
# x_8 = 0.61
# Variável escolhida: x_8 = 0.61
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 2
# Resultado da Relaxação Linear: 22.649
# Variáveis:
# x_0 = 0.00
# x_1 = 0.65
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.76
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_1 = 0.65
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 3
# Resultado da Relaxação Linear: 21.667
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.33
# x_8 = 0.00
# Variável escolhida: x_7 = 0.33
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 4
# Resultado da Relaxação Linear: 21.100
# Variáveis:
# x_0 = 0.30
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 5
# Resultado da Relaxação Linear: 20.800
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.30
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 0
# constr(15):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 6
# Resultado da Relaxação Linear: 20.286
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.43
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_3 = 0.43
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 0
# constr(15):  x_0 = 0
# constr(16):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 7
# Resultado da Relaxação Linear: 19.300
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.30
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 0
# constr(15):  x_0 = 0
# constr(16):  x_4 = 0
# constr(17):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 8
# Resultado da Relaxação Linear: 19.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 9
# Resultado da Relaxação Linear: 13.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.22
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.22
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 10
# Resultado da Relaxação Linear: 18.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.56
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.56
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 11
# Resultado da Relaxação Linear: 18.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.22
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.22
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 12
# Resultado da Relaxação Linear: 17.000
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_2 = 1.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 13
# Resultado da Relaxação Linear: 21.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.33
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.33
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 14
# Resultado da Relaxação Linear: 20.100
# Variáveis:
# x_0 = 0.30
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 1
# constr(15):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 15
# Resultado da Relaxação Linear: 19.800
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.30
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 1
# constr(15):  x_6 = 0
# constr(16):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 16
# Resultado da Relaxação Linear: 19.286
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.43
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_3 = 0.43
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 1
# constr(15):  x_6 = 0
# constr(16):  x_0 = 0
# constr(17):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 17
# Resultado da Relaxação Linear: 18.300
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.30
# x_6 = 0.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.30
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 18
# Resultado da Relaxação Linear: 11.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 1.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 19
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 20
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 21
# Resultado da Relaxação Linear: 19.500
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.25
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_2 = 0.25
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -7 x_0 -9 x_1 -10 x_2 -3 x_3 -6 x_4 - x_5 -9 x_6 -8 x_7 -8 x_8
# Subject To
# constr(0):  2 x_0 + x_1 + 9 x_2 + 6 x_3 + 3 x_4 + 6 x_5 + 10 x_6 + 9 x_7 + x_8 <= 60
# constr(1):  8 x_0 + 6 x_1 + 6 x_2 + 5 x_3 + 2 x_4 + 2 x_5 + 4 x_6 + 3 x_7 + 6 x_8 <= 80
# constr(2):  8 x_0 + x_1 + 3 x_2 + 7 x_3 + x_4 + 4 x_5 + 8 x_6 + 3 x_7 + 4 x_8 <= 30
# constr(3):  6 x_0 + 3 x_1 + 9 x_2 + 5 x_3 + 9 x_4 + 6 x_5 + 9 x_6 + 9 x_7 + 6 x_8 <= 40
# constr(4):  10 x_0 + 8 x_1 + 8 x_2 + 7 x_3 + 10 x_4 + 10 x_5 + 9 x_6 + 9 x_7 + 3 x_8 <= 20
# constr(5):  10 x_0 + 10 x_1 + 10 x_2 + 9 x_3 + 10 x_4 + x_5 + 8 x_6 + 3 x_7 + 10 x_8 <= 90
# constr(6):  10 x_0 + 5 x_1 + 8 x_2 + 2 x_3 + 7 x_4 + 8 x_5 + 6 x_6 + 2 x_7 + 2 x_8 <= 90
# constr(7):  7 x_0 + 9 x_1 + x_2 + 9 x_3 + 5 x_4 + 8 x_5 + 5 x_6 + 9 x_7 + 5 x_8 <= 80
# constr(8):  2 x_0 + 4 x_1 + 6 x_2 + x_3 + 7 x_4 + 9 x_5 + 10 x_6 + x_7 + 7 x_8 <= 80
# constr(9):  8 x_0 + 10 x_1 + 2 x_2 + 6 x_3 + 7 x_4 + 2 x_5 + 2 x_6 + 4 x_7 + 9 x_8 <= 10
# constr(10):  10 x_0 + 9 x_1 + x_2 + 4 x_3 + 2 x_4 + 4 x_5 + 4 x_6 + 8 x_7 + 2 x_8 <= 30
# constr(11):  9 x_0 + 4 x_1 + x_2 + 8 x_3 + 9 x_4 + 5 x_5 + 10 x_6 + 5 x_7 + 8 x_8 <= 30
# constr(12):  x_8 = 0
# constr(13):  x_1 = 0
# constr(14):  x_7 = 1
# constr(15):  x_6 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 22
# Resultado da Relaxação Linear: 18.400
# Variáveis:
# x_0 = 0.20
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.20
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 23
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 24
# Resultado da Relaxação Linear: 9.000
# Variáveis:
# x_0 = 0.00
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 25
# Resultado da Relaxação Linear: 13.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.50
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 1.00
# Variável escolhida: x_2 = 0.50
# Solution Value 3: 19.0

# %%
fres = open(f"resposta4.txt", "r")
print(fres.read())
fres.close()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 1
# Resultado da Relaxação Linear: 13.571
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.71
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.71
# Variável escolhida: x_2 = 0.71
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 2
# Resultado da Relaxação Linear: 13.077
# Variáveis:
# x_0 = 0.38
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.38
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.77
# Variável escolhida: x_3 = 0.38
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 3
# Resultado da Relaxação Linear: 12.684
# Variáveis:
# x_0 = 1.00
# x_1 = 0.39
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.03
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.18
# x_8 = 0.00
# Variável escolhida: x_1 = 0.39
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 4
# Resultado da Relaxação Linear: 12.559
# Variáveis:
# x_0 = 0.77
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.34
# x_8 = 0.47
# Variável escolhida: x_8 = 0.47
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 5
# Resultado da Relaxação Linear: 11.800
# Variáveis:
# x_0 = 0.60
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.70
# x_7 = 0.20
# x_8 = 0.00
# Variável escolhida: x_0 = 0.60
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 6
# Resultado da Relaxação Linear: 10.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.22
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.22
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 7
# Resultado da Relaxação Linear: 9.714
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.29
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.29
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 0
# constr(14):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 8
# Resultado da Relaxação Linear: 9.143
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.29
# x_8 = 0.00
# Variável escolhida: x_7 = 0.29
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 0
# constr(14):  x_4 = 0
# constr(15):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 9
# Resultado da Relaxação Linear: 8.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 1.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 10
# Resultado da Relaxação Linear: 7.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.38
# x_7 = 1.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.38
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 11
# Resultado da Relaxação Linear: 9.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.38
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.38
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 0
# constr(14):  x_4 = 0
# constr(15):  x_5 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 12
# Resultado da Relaxação Linear: 7.500
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 1.00
# x_6 = 0.00
# x_7 = 0.38
# x_8 = 0.00
# Variável escolhida: x_7 = 0.38
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 13
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 14
# Resultado da Relaxação Linear: 9.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 1.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 15
# Resultado da Relaxação Linear: 11.000
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.50
# x_8 = 0.00
# Variável escolhida: x_7 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 16
# Resultado da Relaxação Linear: 10.333
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.17
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.17
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 1
# constr(14):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 17
# Resultado da Relaxação Linear: 10.200
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.20
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 1
# constr(14):  x_7 = 0
# constr(15):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 18
# Resultado da Relaxação Linear: 9.900
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.10
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.10
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 0
# constr(13):  x_0 = 1
# constr(14):  x_7 = 0
# constr(15):  x_6 = 0
# constr(16):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 19
# Resultado da Relaxação Linear: 9.000
# Variáveis:
# x_0 = 1.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 20
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 21
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 22
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 23
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 24
# Resultado da Relaxação Linear: 11.250
# Variáveis:
# x_0 = 0.06
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.19
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 1.00
# Variável escolhida: x_4 = 0.19
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 25
# Resultado da Relaxação Linear: 10.841
# Variáveis:
# x_0 = 0.11
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.20
# x_8 = 1.00
# Variável escolhida: x_7 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 1
# constr(13):  x_4 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 26
# Resultado da Relaxação Linear: 10.500
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.25
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 1.00
# Variável escolhida: x_5 = 0.25
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 1
# constr(13):  x_4 = 0
# constr(14):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 27
# Resultado da Relaxação Linear: 10.286
# Variáveis:
# x_0 = 0.14
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 1.00
# Variável escolhida: x_0 = 0.14
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 1
# constr(13):  x_4 = 0
# constr(14):  x_7 = 0
# constr(15):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 28
# Resultado da Relaxação Linear: 10.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.12
# x_7 = 0.00
# x_8 = 1.00
# Variável escolhida: x_6 = 0.12
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 0
# constr(11):  x_1 = 0
# constr(12):  x_8 = 1
# constr(13):  x_4 = 0
# constr(14):  x_7 = 0
# constr(15):  x_5 = 0
# constr(16):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 29
# Resultado da Relaxação Linear: 9.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 1.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 30
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 31
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 32
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 33
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 34
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 35
# Resultado da Relaxação Linear: 8.800
# Variáveis:
# x_0 = 0.20
# x_1 = 1.00
# x_2 = 0.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.20
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 36
# Resultado da Relaxação Linear: 12.541
# Variáveis:
# x_0 = 0.00
# x_1 = 0.03
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.59
# Variável escolhida: x_8 = 0.59
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 37
# Resultado da Relaxação Linear: 12.368
# Variáveis:
# x_0 = 0.29
# x_1 = 0.39
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_1 = 0.39
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 38
# Resultado da Relaxação Linear: 11.308
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.42
# x_7 = 0.23
# x_8 = 0.00
# Variável escolhida: x_6 = 0.42
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# constr(12):  x_1 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 39
# Resultado da Relaxação Linear: 11.132
# Variáveis:
# x_0 = 0.21
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.57
# x_8 = 0.00
# Variável escolhida: x_7 = 0.57
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# constr(12):  x_1 = 0
# constr(13):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 40
# Resultado da Relaxação Linear: 10.600
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.60
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.60
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# constr(12):  x_1 = 0
# constr(13):  x_6 = 0
# constr(14):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 41
# Resultado da Relaxação Linear: 10.000
# Variáveis:
# x_0 = 0.33
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.33
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# constr(12):  x_1 = 0
# constr(13):  x_6 = 0
# constr(14):  x_7 = 0
# constr(15):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 42
# Resultado da Relaxação Linear: 9.700
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.30
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.30
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 0
# constr(10):  x_3 = 1
# constr(11):  x_8 = 0
# constr(12):  x_1 = 0
# constr(13):  x_6 = 0
# constr(14):  x_7 = 0
# constr(15):  x_5 = 0
# constr(16):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 43
# Resultado da Relaxação Linear: 7.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 0.00
# x_3 = 1.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 44
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 45
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 46
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 47
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 48
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 49
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 50
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 51
# Resultado da Relaxação Linear: 13.486
# Variáveis:
# x_0 = 0.00
# x_1 = 0.32
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.14
# Variável escolhida: x_1 = 0.32
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 52
# Resultado da Relaxação Linear: 12.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.50
# x_8 = 0.00
# Variável escolhida: x_7 = 0.50
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 53
# Resultado da Relaxação Linear: 11.800
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.20
# Variável escolhida: x_8 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 54
# Resultado da Relaxação Linear: 11.333
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.17
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_6 = 0.17
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# constr(12):  x_8 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 55
# Resultado da Relaxação Linear: 11.200
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.20
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_5 = 0.20
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# constr(12):  x_8 = 0
# constr(13):  x_6 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 56
# Resultado da Relaxação Linear: 11.000
# Variáveis:
# x_0 = 0.11
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_0 = 0.11
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# constr(12):  x_8 = 0
# constr(13):  x_6 = 0
# constr(14):  x_5 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 57
# Resultado da Relaxação Linear: 11.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.14
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_3 = 0.14
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# constr(12):  x_8 = 0
# constr(13):  x_6 = 0
# constr(14):  x_5 = 0
# constr(15):  x_0 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 58
# Resultado da Relaxação Linear: 10.900
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.10
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# Variável escolhida: x_4 = 0.10
#
# Restrições:
#
# \Problem name:
#
# Minimize
# OBJROW: -9 x_0 -7 x_1 -10 x_2 -7 x_3 -9 x_4 -6 x_5 -8 x_6 -4 x_7 -9 x_8
# Subject To
# constr(0):  4 x_0 + 9 x_1 + 4 x_2 + x_3 + 9 x_4 + 6 x_5 + 3 x_6 + 6 x_7 + x_8 <= 40
# constr(1):  3 x_0 + 7 x_1 + 8 x_2 + 7 x_3 + 6 x_4 + 3 x_5 + 5 x_6 + 9 x_7 + 4 x_8 <= 80
# constr(2):  9 x_0 + 3 x_1 + 6 x_2 + 5 x_3 + 7 x_4 + x_5 + x_6 + 3 x_7 + 9 x_8 <= 40
# constr(3):  5 x_0 + 9 x_1 + 6 x_2 + 5 x_3 + 9 x_4 + 7 x_5 + 8 x_6 + 7 x_7 + 8 x_8 <= 10
# constr(4):  7 x_0 + 7 x_1 + 4 x_2 + x_3 + 3 x_4 + 4 x_5 + 8 x_6 + x_7 + 9 x_8 <= 10
# constr(5):  x_0 + 6 x_1 + 6 x_2 + x_3 + 6 x_4 + 7 x_5 + 3 x_6 + 8 x_7 + 7 x_8 <= 10
# constr(6):  6 x_0 + 6 x_1 + 8 x_2 + 6 x_3 + 10 x_4 + 8 x_5 + x_6 + 4 x_7 + 4 x_8 <= 70
# constr(7):  9 x_0 + x_1 + 9 x_2 + 7 x_3 + 10 x_4 + 5 x_5 + 6 x_6 + 2 x_7 + 5 x_8 <= 10
# constr(8):  2 x_0 + 7 x_1 + 6 x_2 + 5 x_3 + x_4 + x_5 + 9 x_6 + 2 x_7 + x_8 <= 20
# constr(9):  x_2 = 1
# constr(10):  x_1 = 0
# constr(11):  x_7 = 0
# constr(12):  x_8 = 0
# constr(13):  x_6 = 0
# constr(14):  x_5 = 0
# constr(15):  x_0 = 0
# constr(16):  x_3 = 0
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#  0 <= x_5 <= 1
#  0 <= x_6 <= 1
#  0 <= x_7 <= 1
#  0 <= x_8 <= 1
# End
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 59
# Resultado da Relaxação Linear: 10.000
# Variáveis:
# x_0 = 0.00
# x_1 = 0.00
# x_2 = 1.00
# x_3 = 0.00
# x_4 = 0.00
# x_5 = 0.00
# x_6 = 0.00
# x_7 = 0.00
# x_8 = 0.00
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 60
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 61
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 62
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 63
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 64
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 65
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 66
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# Iteração 67
#
# Solution Value 4: 10.0
